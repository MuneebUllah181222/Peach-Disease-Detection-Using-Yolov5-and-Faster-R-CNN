# %% [markdown]
# **To start off with YOLOv5 we first clone the YOLOv5 repository and install dependencies. This will set up our programming environment to be ready to running object detection training and inference command**

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13149, done.
# remote: Counting objects: 100% (305/305), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 13149 (delta 210), reused 245 (delta 169), pack-reused 12844
# Receiving objects: 100% (13149/13149), 13.10 MiB | 8.30 MiB/s, done.
# Resolving deltas: 100% (9043/9043), done.

# %%
 # install dependencies
# !pip install -U -r yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
import torch
from IPython.display import Image  # for displaying images

# %%
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-183-gc98128f Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt  --img 640 --conf 0.2 --source "/content/drive/MyDrive/Peach Dataset/images/val"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/Peach Dataset/images/val, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-183-gc98128f Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/69 /content/drive/MyDrive/Peach Dataset/images/val/brown rot  (1).jpg: 640x480 1 healthy, 1 shot_hole, 13.0ms
# image 2/69 /content/drive/MyDrive/Peach Dataset/images/val/brown rot  (11).jpg: 480x640 3 healthys, 2 shot_holes, 12.7ms
# ...

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 181 kB 62.3 MB/s
# ...
#      |████████████████████████████████| 162 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 140 kB 55.4 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=12e12428e08172f24ae915e998015bf9e329c8fc98e4852ff249097371ac9edd
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# %tensorboard --logdir
